# %%
import numpy as np
import pandas as pd

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link1 = 'https://drive.google.com/file/d/1-7kTNJ07pIGffkVlgM4sbb_5ka5hKn8g/view?usp=sharing'
link2 = 'https://drive.google.com/file/d/1dPoVlC9OO1S-5KljJEb7LAROFRNBT6oY/view?usp=sharing'
link3 = 'https://drive.google.com/file/d/1grkB3jlDMdBa8jp9wYccZlKGf6bvjcoa/view?usp=sharing'
link4 = 'https://drive.google.com/file/d/16s1EjgHKqp-V7T3d-unt8bQGIcDtkPjz/view?usp=sharing'
link5 = 'https://drive.google.com/file/d/15Na-0f0gwE-07ltaWlJa5gSYEt_-tX37/view?usp=sharing'
link6 = 'https://drive.google.com/file/d/1FpZklfTy-5t0rdMQlzgJIvvubjbmRM47/view?usp=sharing'
link7 = 'https://drive.google.com/file/d/1WfEb825p-ZoNZFu-uk7NdlmYehouHY94/view?usp=sharing'
link8 = 'https://drive.google.com/file/d/1_TAWkCAwqYeV5vuTXMFuX2smZoILaxFo/view?usp=sharing'
link9 = 'https://drive.google.com/file/d/1cLliIgstZEHBMCw4O3IrXTigV-hDA_Ro/view?usp=sharing'
link10 = 'https://drive.google.com/file/d/1Dqk0maWFDr0rzuEMgAfSckliyNWH_alh/view?usp=sharing'

# %%
# to get the id part of the file
id = link1.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p1.csv') 
 
df1 = pd.read_csv('BERTsent_Feb_Train_p1.csv')
print(df1)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0                0  @k_c12345 Brother this called link 👇\nhttps://...      1
# 1                1  Ukraine invasion: Who is President Volodymyr Z...      1
# 2                2  So it now looks like we're in a new phase of t...      0
# 3                3  @vanderbellen @karlnehammer TOP RUSSIAN AGGRES...      0
# 4                4  @ZelenskyyUa @EmmanuelMacron Ukraine won't fal...      1
# ...            ...                                                ...    ...
# 178250      178250  US, NATO seek to shore up defenses as Russia-U...      1
# 178251      178251  @KenHolmes10 @graceblakeley @zarahsultana The ...      0
# 178252      178252  @Rajeev_vajeer @MichaelaNewell_ @ZelenskyyUa @...      1
# 178253      178253  @culturisk America can't do shit rn because Uk...      0
# 178254      178254  @sertacdarcan @AlarKaris STOP RUSSIAN AGGRESSI...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link2.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p2.csv') 
 
df2 = pd.read_csv('BERTsent_Feb_Train_p2.csv')
print(df2)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0           178255  Sadly, don’t believe Ukraine has much time lef...      0
# 1           178256  BREAKING: Taliban Calls For Peace Between Russ...      1
# 2           178257  @RussiaTravelEN @Russia Sorry these are all in...      0
# 3           178258  @DropSquad_52 @Russia What are you saying thou...      0
# 4           178259  As missiles rained down, nearly 400,000 civili...      0
# ...            ...                                                ...    ...
# 178250      356505  Here are all the major US and European compani...      1
# 178251      356506  @karanrajan @YusufDFI He is hell bent on demon...      0
# 178252      356507  Vladimir Putin sits atop a crumbling pyramid o...      1
# 178253      356508  @dun_dreams You don't get. This is not about m...      0
# 178254      356509  Russian: hmmm, where do I spend my holiday?\nE...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link3.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p3.csv') 
 
df3 = pd.read_csv('BERTsent_Feb_Train_p3.csv')
print(df3)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0           356510  Russia's invasion of Ukraine has sparked a hum...      0
# 1           356511  @Atalanta_BC Can you tell this son of a bitch ...      0
# 2           356512  @DeutscheWelle USA and Germany made sure commo...      0
# 3           356513  -It appears Russia has issued a NOTAM for the ...      1
# 4           356514  'The stakes could not possibly be higher' | Wi...      0
# ...            ...                                                ...    ...
# 178250      534760  @dhume @RShivshankar Got a fwded msg from a RW...      1
# 178251      534761  "#Russia has never been under threat from @NAT...      1
# 178252      534762  @akarl_smith Tucker Carlson never supported Pu...      0
# 178253      534763  SWIFT is absolutely necessary #Germans #OlafSc...      0
# 178254      534764  @UN STOP RUSSIAN AGGRESSION AGAINST #UKRAINE. ...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link4.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p4.csv') 
 
df4 = pd.read_csv('BERTsent_Feb_Train_p4.csv')
print(df4)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0           534765  "UN General Assembly votes to condemn Russia o...      1
# 1           534766  @SarahSp58588539 I think they will be making a...      1
# 2           534767  #PutinHitler I don’t understand why Belarus is...      0
# 3           534768  @Sonny1366 @TheRickWilson You are parroting Pu...      0
# 4           534769  of course the conflict hasnt nearly been as se...      0
# ...            ...                                                ...    ...
# 178250      713015  @BOUSMAH79199901 @SecBlinken What are you talk...      0
# 178251      713016  @Ukraine @MFA_Ukraine @APUkraine @GeneralStaff...      0
# 178252      713017  New signs put up to greet Russia forces in Ukr...      2
# 178253      713018  For #peace in the #world\nIn #Ukraine  in #Rus...      2
# 178254      713019  @kjtweet @andersostlund @SecBlinken @UN If you...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link5.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p5.csv') 
 
df5 = pd.read_csv('BERTsent_Feb_Train_p5.csv')
print(df5)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0           713020  Why is cnn not in Ukraine covering the war. Re...      0
# 1           713021  #Russianpeople, you can resolve this. Is killi...      0
# 2           713022  @EssexPR It’s so not their fault. This is Puti...      0
# 3           713023  Russia's chief negotiator Vladimir Medinsky sa...      1
# 4           713024  It's no coincidence that as the West declares ...      0
# ...            ...                                                ...    ...
# 178250      891270  Russia-Ukraine war LIVE: Russian convoy advanc...      1
# 178251      891271  115 Nigerian men offer to join Ukraine in figh...      1
# 178252      891272  @WSJ STOP RUSSIA NOW‼️‼️‼️‼️\nHELP #Kharkiv NO...      0
# 178253      891273  @ZelenskyyUa according global values india giv...      1
# 178254      891274  #Belarus: Now that Russia is weakened by the f...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link6.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p6.csv') 
 
df6 = pd.read_csv('BERTsent_Feb_Train_p6.csv')
print(df6)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0           891275  Turkey says Ukraine-Russia talks unlikely on W...      1
# 1           891276  EUR/USD, EUR/GBP and AUD/USD sidelined as trad...      1
# 2           891277  Russia invades Ukraine the first war I see on ...      0
# 3           891278  @TelegraphWorld\n\nStill not enough. \n\nThe w...      0
# 4           891279  #UkraineRussia #UkraineWar \nhttps://t.co/tzQ8...      1
# ...            ...                                                ...    ...
# 178250     1069525  #Kyiv says 352 civilians have been killed, inc...      0
# 178251     1069526  @_natrimorrigna Obviously with adding the Balt...      1
# 178252     1069527  @Mignear @hnjc99 @Inc02 @KyivIndependent Who c...      0
# 178253     1069528  If you are an international anything with the ...      0
# 178254     1069529  @nickwestes we didn't push russia-USSR disolve...      1
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link7.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p7.csv') 
 
df7 = pd.read_csv('BERTsent_Feb_Train_p7.csv')
print(df7)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0          1069530  India has avoided publicly denouncing Russia f...      1
# 1          1069531  ⚡️Video of the shelling of the TV tower.\n#Rus...      1
# 2          1069532  We hope Russia obeys rules of engagement, says...      1
# 3          1069533  @anonukr You guys should stop pushing Ukrainia...      0
# 4          1069534      Follow @m_suchkov for Russia/Ukraine updates.      1
# ...            ...                                                ...    ...
# 178250     1247780  Ukraine invaded, Russia under martial law.\n\n...      1
# 178251     1247781  Guten Tag from Germany where I’m helping out t...      1
# 178252     1247782  Business Insider - Bitcoin's strength is being...      1
# 178253     1247783  @Niyiafrika02 @Ukraine @Russia Our politicians...      1
# 178254     1247784  Being realistic and hard headed, if Russia is ...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link8.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p8.csv') 
 
df8 = pd.read_csv('BERTsent_Feb_Train_p8.csv')
print(df8)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0          1247785  @AlexCobb_ Nah, all restrictions ended just be...      1
# 1          1247786  #Zalensky BLATANTLY LIED on Twitter about #Tur...      0
# 2          1247787  @meijer I'm calling on you to remove all Russi...      1
# 3          1247788  @BorisJohnson STOP RUSSIAN AGGRESSION AGAINST ...      0
# 4          1247789  @ua_parliament @NATO @eucopresident @vonderley...      0
# ...            ...                                                ...    ...
# 178250     1426035  @cricket_ind1 @KremlinRussia_E So Keiling Sevi...      0
# 178251     1426036  Ukraine: The Most Dangerous Problem in the Wor...      1
# 178252     1426037  @markminervini @smigel_david Russia is not sca...      1
# 178253     1426038  @PatPromoterNFT  Hey check out my NFT that I d...      1
# 178254     1426039  @Bluertwo Not me. It's an empty gesture. Does ...      0
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link9.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p9.csv') 
 
df9 = pd.read_csv('BERTsent_Feb_Train_p9.csv')
print(df9)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0          1426040  #SupportUkraine @NastiaPav (Russian Tennis 🎾 P...      2
# 1          1426041  @I_Arquam 🤔🤔I apologize but I really don't und...      0
# 2          1426042  @TomCottonAR You can’t be this ignorant to thi...      0
# 3          1426043  @DmytroKuleba Ukraine was an ally of Hitler an...      1
# 4          1426044  More and more sports are following the appeal ...      1
# ...            ...                                                ...    ...
# 178250     1604290  #TheWarDebate | 'The NATO &amp; US seem set to...      0
# 178251     1604291  @LatestAnonPress US, Israel, NATO Bombing othe...      0
# 178252     1604292  @riabronsgeest @KremlinRussia_E People also li...      0
# 178253     1604293  @ianbremmer So that NATO can box in russia, if...      0
# 178254     1604294  @nibelung1001 @Aleks_Kovalyuk @PrytSLU Ukraine...      1
#
#         Negative   Neutral  Positive
# ...

# %%
# to get the id part of the file
id = link10.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('BERTsent_Feb_Train_p10.csv') 
 
df10 = pd.read_csv('BERTsent_Feb_Train_p10.csv')
print(df10)
# Out:
#         Unnamed: 0                                               text  Label  \
# 0          1604295  Russia-Ukraine Crisis Live: Have taken control...      1
# 1          1604296  Video shows Ukrainian ‘tank man’ trying to blo...      0
# 2          1604297  WarnerMedia, the corporation behind movies set...      1
# 3          1604298  Every Military expert keeps pointing out you c...      0
# 4          1604299  @AnnePM4 @JKbrighton @vonderburchard @alexwick...      1
# ...            ...                                                ...    ...
# 178251     1782546  @UNESCO Dear UNESCO. I'm a peaceful citizen of...      0
# 178252     1782547  This is not Ukraine vs Russia war. This is a c...      0
# 178253     1782548  Russia 🇷🇺 is warn... Don't provoke the 4nation...      1
# 178254     1782549  Africa Report: How Africa factors in #RussiaUk...      1
# 178255     1782550  @BanteSaket @LukeMackay13 @Reporter_indian I l...      0
#
#         Negative   Neutral  Positive
# ...

# %%
#make one dataframe
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]
df = pd.concat(frames)

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#                                                      text  Label  Negative  \
# 0       @k_c12345 Brother this called link 👇\nhttps://...      1  0.335056
# 1       Ukraine invasion: Who is President Volodymyr Z...      1  0.272589
# 2       So it now looks like we're in a new phase of t...      0  0.864383
# 3       @vanderbellen @karlnehammer TOP RUSSIAN AGGRES...      0  0.837160
# 4       @ZelenskyyUa @EmmanuelMacron Ukraine won't fal...      1  0.015998
# ...                                                   ...    ...       ...
# 178251  @UNESCO Dear UNESCO. I'm a peaceful citizen of...      0  0.576491
# 178252  This is not Ukraine vs Russia war. This is a c...      0  0.970587
# 178253  Russia 🇷🇺 is warn... Don't provoke the 4nation...      1  0.198318
# 178254  Africa Report: How Africa factors in #RussiaUk...      1  0.019901
# 178255  @BanteSaket @LukeMackay13 @Reporter_indian I l...      0  0.971157
#
#          Neutral  Positive
# 0       0.656753  0.008192
# ...

# %%
#save fale to drive
from google.colab import drive
drive.mount('drive')

df.to_csv('BERTsent_Feb_Train.csv')
# !cp BERTsent_Feb_Train.csv "/content/drive/My Drive/Colab Notebooks/BERTsent/February"
# Out:
# Mounted at drive

# %%
#0=negative, 1=netral, 2 =positive
df
# Out:
#                                                      text  Label  Negative  \
# 0       @k_c12345 Brother this called link 👇\nhttps://...      1  0.335056
# 1       Ukraine invasion: Who is President Volodymyr Z...      1  0.272589
# 2       So it now looks like we're in a new phase of t...      0  0.864383
# 3       @vanderbellen @karlnehammer TOP RUSSIAN AGGRES...      0  0.837160
# 4       @ZelenskyyUa @EmmanuelMacron Ukraine won't fal...      1  0.015998
# ...                                                   ...    ...       ...
# 178251  @UNESCO Dear UNESCO. I'm a peaceful citizen of...      0  0.576491
# 178252  This is not Ukraine vs Russia war. This is a c...      0  0.970587
# 178253  Russia 🇷🇺 is warn... Don't provoke the 4nation...      1  0.198318
# 178254  Africa Report: How Africa factors in #RussiaUk...      1  0.019901
# 178255  @BanteSaket @LukeMackay13 @Reporter_indian I l...      0  0.971157
#
#          Neutral  Positive
# 0       0.656753  0.008192
# ...

# %%
results = df['Label'].value_counts()

# %%
results
# Out:
# 0    903727
# 1    828163
# 2     50661
# Name: Label, dtype: int64

# %%
from google.colab import files
import matplotlib.pyplot as plt

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Negative', 'Neutral', 'Positive'
sizes = [903727, 828163, 50661]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig('BERTsent_Feb_Results.png')
files.download('BERTsent_Feb_Results.png')
plt.show()
